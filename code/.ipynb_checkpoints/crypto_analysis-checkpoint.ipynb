# %% [markdown]
# # CRYPTO ANALYSIS AND ML MODEL

# %%
import pandas as pd 
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import itertools
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.neighbors import KNeighborsRegressor
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
from pylab import rcParams

def correlations_analysis(df):
    display(df.corr())
    sns.pairplot(df)
    plt.show()
    sns.heatmap(df.corr(), annot=True)
    plt.show()

# %%
crypto_df = pd.read_csv("../final_data/crypto_series.csv")
# crypto_df = crypto_df.set_index('date')
crypto_df
# Out:
#             date        btc_p      ltc_p      eth_p     xrp_p    doge_p
# 0     04/01/2016    426.57000    3.49300     0.9600  0.007418  0.000224
# 1     06/01/2016    431.32000    3.47900     0.9426  0.005809  0.000234
# 2     07/01/2016    429.99000    3.44000     0.9500  0.006787  0.000302
# 3     08/01/2016    457.88354    3.58399     0.9400  0.005906  0.000223
# 4     11/01/2016    449.13000    3.52817     1.0000  0.008102  0.000221
# ...          ...          ...        ...        ...       ...       ...
# 1282  20/12/2021  46688.40000  153.22000  3924.3700  0.879828  0.879828
# 1283  21/12/2021  46898.10000  152.75000  3941.8200  0.947646  0.947646
# 1284  22/12/2021  48925.90000  154.70000  4018.2000  0.954699  0.954699
# 1285  23/12/2021  48624.90000  155.41000  3980.4400  0.993285  0.993285
# 1286  29/12/2021  47548.10000  145.64000  3792.0900  0.816714  0.816714
#
# [1287 rows x 6 columns]

# %%
# correlations_analysis(crypto_df)

# %%
# # # Let's plot the features to visually inspect them.
# # Scatter plots

# ######### Vs BTC as target #############
# plt.scatter(x=crypto_df['ltc_p'], y=crypto_df['btc_p'])
# plt.title("LTC/BTC")
# plt.show()
# plt.scatter(x=crypto_df['eth_p'], y=crypto_df['btc_p'])
# plt.title("ETH/BTC")
# plt.show()
# plt.scatter(x=crypto_df['xrp_p'], y=crypto_df['btc_p'])
# plt.title("XRP/BTC")
# plt.show()
# plt.scatter(x=crypto_df['doge_p'], y=crypto_df['btc_p'])
# plt.title("DOGE/BTC")
# plt.show()

# %% [markdown]
# # TIME SERIES ANALYSIS

# %%
crypto_df = crypto_df.set_index('date')

# %%
# # # Check features for Seasonality with the complete DF curr_btc:

# # # Standardize
# # scaler = MinMaxScaler()
# # curr_btc_sc = scaler.fit_transform(crypto_df)

# # # Convert to DF
# # curr_btc_s = pd.DataFrame(crypto_df, columns=crypto_df.columns)


# #period=214 shows the 214 days of trade as avreage on records 
# rcParams['figure.figsize'] = 18, 8

# # res = sm.tsa.seasonal_decompose(crypto_df.btc_p, period=214,model='additive')  
# # print('BTC  mean:' ,crypto_df.btc_p.mean())
# # fig = res.plot()

# # res = sm.tsa.seasonal_decompose(crypto_df.ltc_p, period=214,model='additive')
# # print('LTC  mean:' ,crypto_df.ltc_p.mean())
# # fig = res.plot()

# # res = sm.tsa.seasonal_decompose(crypto_df.eth_p, period=214,model='additive') 
# # print('ETH  mean:' ,crypto_df.eth_p.mean())
# # fig = res.plot()

# res = sm.tsa.seasonal_decompose(crypto_df.xrp_p, period=214,model='additive') 
# print('XRP  mean:' ,crypto_df.xrp_p.mean())
# fig = res.plot()

# res = sm.tsa.seasonal_decompose(crypto_df.doge_p, period=214,model='additive') 
# print('DOGE mean:' ,crypto_df.doge_p.mean())
# fig = res.plot()
# Out:
# BTC  mean: 12438.668752377622
# LTC  mean: 76.02117520590517
# ETH  mean: 630.9027437218336
# XRP  mean: 0.3736378009160842
# DOGE mean: 0.09187007896658898

# %% [markdown]
# We can cconclude that nor the currencies or BTC follow any significant seasonality.
#
# The Seasonal Descomposer has found patterns lets say woth a 10% var range,  but then the errors where 25% range>

# %%
lag_plot(crypto_df.btc_p) 
plt.title('BTC')
plt.show()
lag_plot(crypto_df.ltc_p)
plt.title('LTC')
plt.show()
lag_plot(crypto_df.eth_p) 
plt.title('ETH')
plt.show()
lag_plot(crypto_df.xrp_p) 
plt.title('XRP')
plt.show()
lag_plot(crypto_df.doge_p) 
plt.title('DOGE')
plt.show()

# %%
#########################################################################################
# STRONG AUTOCORRELATION (The value for period 't' is strongly dependent from value (t-1))
# They are stringly autocorrelated at the beggigning, more stable, then flcutuations are higher when the value increases
# There is a break n the plot on BTC due t big fluctuations (EMOTION RESPONSE ? )
#########################################################################################

# %%
# # Separate sub DF 
BTC = crypto_df[['btc_p']]
LTC = crypto_df[['ltc_p']]
ETH = crypto_df[['eth_p']]
XRP = crypto_df[['xrp_p']]
DOGE= crypto_df[['doge_p']]

# %%
crypto_df.btc_p
# Out:
# date
# 04/01/2016      426.57000
# 06/01/2016      431.32000
# 07/01/2016      429.99000
# 08/01/2016      457.88354
# 11/01/2016      449.13000
#                  ...
# 20/12/2021    46688.40000
# 21/12/2021    46898.10000
# 22/12/2021    48925.90000
# 23/12/2021    48624.90000
# 29/12/2021    47548.10000
# Name: btc_p, Length: 1287, dtype: float64

# %%
# # # Train test per Crypto:
# # BTC
# btc_train, btc_test = BTC[:-50], BTC[-50:]
# # LTC
# ltc_train, ltc_test = LTC[:-50], LTC[-50:]
# # ETH
# eth_train, eth_test = ETH[:-50], ETH[-50:]
# # XRP
# xrp_train, xrp_test = XRP[:-50], XRP[-50:]
# # DOGE
# doge_train, doge_test = DOGE[:-50], DOGE[-50:]

# # Convert to DFx
# btc_train = pd.DataFrame(btc_train)
# btc_test = pd.DataFrame(btc_train)
# ltc_train = pd.DataFrame(ltc_train)
# ltc_test = pd.DataFrame(ltc_train)
# eth_train = pd.DataFrame(eth_train)
# eth_test = pd.DataFrame(eth_train)
# xrp_train = pd.DataFrame(xrp_train)
# xrp_test = pd.DataFrame(xrp_train)
# doge_train = pd.DataFrame(doge_train)
# doge_test = pd.DataFrame(doge_train)

# %%
# AD FULER TEST FOR STATIONALITY 
# Check for stationarity of the time-series data
# We will look for p-value. In case, p-value is less than 0.05, the time series
# data can said to have stationarity
def stationary_test(df):
        btc_stationarityTest = adfuller(df, autolag='AIC')
        if btc_stationarityTest[1] <= 0.05:
            return print(" is stationary")
        else:
            return print(" is NOT stationary")

# %% [markdown]
# # BTC

# %%
# AD FULER TEST FOR STATIONALITY 
stationary_test(crypto_df[['btc_p']])
# Out:
#  is NOT stationary

# %%
# # Check BTC Time Series for Seasonality:
#period=214 shows the 214 days of trade as avreage on records 
rcParams['figure.figsize'] = 18, 8

res = sm.tsa.seasonal_decompose(crypto_df.btc_p, period=214,model='additive')  
print('BTC  mean:' ,crypto_df.btc_p.mean())
fig = res.plot()
# Out:
# BTC  mean: 12438.668752377622

# %%
# Next step is to find the order of AR model to be trained
# for this, we will plot partial autocorrelation plot to assess
# the direct effect of past data on future data
pacf_100 = plot_pacf(crypto_df['btc_p'], lags=100)

# %%
# AUTOREGRESSION MODEL:
    # Train Test Split
train_btc = crypto_df['btc_p'][:len(crypto_df)-100]
test_btc = crypto_df['btc_p'][len(crypto_df)-100:]
    # Instantiate and fit the AR model with training data
ar_btc = AutoReg(train_data, lags=300).fit()
    # Make the predictions
pred_ar_btc = ar_btc.predict(start=len(train_btc), end=(len(crypto_df)-1), dynamic=False)
print(ar_btc.summary())
    # Accuracy
MSE_AR_btc = mean_squared_error(test_btc, pred_ar_btc)
RMSE_AR_btc = math.sqrt(MSE_AR_btc)
pred_ar_btc_check = pred_ar_btc.reset_index(drop=True)
result_check_btc
    # Plot the prediction vs test data
plt.plot(pred_ar_btc_check, color='red')
plt.plot(result_check_btc, color='blue')

print("Root Mean Square Error:", RMSE_AR_btc)
print("Mean Square Error:     ",MSE_AR_btc)
print("error %:               " , RMSE_AR_btc/np.mean(btc_test))
# Out:
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/deterministic.py:147: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Int64Indexes with a unit increment support extending. The index is set will contain the position relative to the data length.
#   warnings.warn(
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                  btc_p   No. Observations:                 1187
# Model:                   AutoReg(300)   Log Likelihood               -7116.716
# Method:               Conditional MLE   S.D. of innovations            738.349
# Date:                Thu, 11 Aug 2022   AIC                             13.890
# Time:                        16:10:14   BIC                             15.520
# Sample:                           300   HQIC                            14.513
#                                  1187
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -11.4387     58.747     -0.195      0.846    -126.582     103.704
# btc_p.L1       1.0391      0.034     30.813      0.000       0.973       1.105
# btc_p.L2       0.0691      0.049      1.422      0.155      -0.026       0.164
# btc_p.L3      -0.1689      0.049     -3.470      0.001      -0.264      -0.073
# btc_p.L4       0.2018      0.049      4.112      0.000       0.106       0.298
# btc_p.L5      -0.0834      0.050     -1.684      0.092      -0.180       0.014
# btc_p.L6      -0.2633      0.050     -5.312      0.000      -0.361      -0.166
# btc_p.L7       0.2625      0.050      5.212      0.000       0.164       0.361
# btc_p.L8      -0.0938      0.051     -1.836      0.066      -0.194       0.006
# btc_p.L9      -0.0765      0.051     -1.495      0.135      -0.177       0.024
# btc_p.L10      0.1633      0.051      3.199      0.001       0.063       0.263
# btc_p.L11     -0.0208      0.051     -0.406      0.685      -0.121       0.080
# btc_p.L12     -0.0056      0.051     -0.109      0.913      -0.106       0.095
# btc_p.L13      0.0329      0.051      0.641      0.521      -0.068       0.134
# btc_p.L14      0.0313      0.051      0.609      0.543      -0.069       0.132
# btc_p.L15     -0.0171      0.051     -0.332      0.740      -0.118       0.084
# btc_p.L16     -0.1186      0.051     -2.311      0.021      -0.219      -0.018
# btc_p.L17      0.0400      0.051      0.784      0.433      -0.060       0.140
# btc_p.L18      0.0695      0.051      1.356      0.175      -0.031       0.170
# AR.128            0.0736           +0.9995j            1.0022            0.2383
# AR.129            0.0940           -1.0010j            1.0054           -0.2351
# AR.130            0.0940           +1.0010j            1.0054            0.2351
# AR.131            0.1144           -0.9986j            1.0051           -0.2319
# AR.132            0.1144           +0.9986j            1.0051            0.2319
# AR.133           -0.1101           -0.9930j            0.9991           -0.2676
# AR.134           -0.1101           +0.9930j            0.9991            0.2676
# AR.135           -0.2379           -0.9676j            0.9964           -0.2884
# AR.136           -0.2379           +0.9676j            0.9964            0.2884
# AR.137            0.1987           -0.9710j            0.9911           -0.2179
# AR.138            0.1987           +0.9710j            0.9911            0.2179
# AR.139            0.1367           -0.9957j            1.0051           -0.2283
# AR.140            0.1367           +0.9957j            1.0051            0.2283
# AR.141            0.1767           -0.9855j            1.0012           -0.2218
# AR.142            0.1767           +0.9855j            1.0012            0.2218
# AR.143            0.2283           -0.9752j            1.0016           -0.2134
# AR.144            0.2283           +0.9752j            1.0016            0.2134
# AR.145            0.1598           -0.9915j            1.0043           -0.2246
# AR.146            0.1598           +0.9915j            1.0043            0.2246
# AR.147            0.2659           -0.9639j            1.0000           -0.2072
# AR.148            0.2659           +0.9639j            1.0000            0.2072
# AR.149           -0.1255           -0.9927j            1.0006           -0.2700
# AR.150           -0.1255           +0.9927j            1.0006            0.2700
# AR.151           -0.1427           -0.9940j            1.0041           -0.2727
# AR.152           -0.1427           +0.9940j            1.0041            0.2727
# AR.153            0.2440           -0.9836j            1.0134           -0.2113
# AR.154            0.2440           +0.9836j            1.0134            0.2113
# AR.155            0.2861           -0.9609j            1.0026           -0.2039
# AR.156            0.2861           +0.9609j            1.0026            0.2039
# AR.157            0.3072           -0.9540j            1.0022           -0.2004
# AR.158            0.3072           +0.9540j            1.0022            0.2004
# AR.159            0.3279           -0.9471j            1.0022           -0.1970
# AR.160            0.3279           +0.9471j            1.0022            0.1970
# AR.161            0.3487           -0.9412j            1.0037           -0.1935
# AR.162            0.3487           +0.9412j            1.0037            0.1935
# AR.163            0.3696           -0.9304j            1.0012           -0.1898
# AR.164            0.3696           +0.9304j            1.0012            0.1898
# AR.165            0.3874           -0.9223j            1.0004           -0.1867
# AR.166            0.3874           +0.9223j            1.0004            0.1867
# AR.167            0.4072           -0.9082j            0.9953           -0.1829
# AR.168            0.4072           +0.9082j            0.9953            0.1829
# AR.169            0.4348           -0.8939j            0.9940           -0.1779
# AR.170            0.4348           +0.8939j            0.9940            0.1779
# AR.171            0.9962           -0.0000j            0.9962           -0.0000
# AR.172            0.4508           -0.9030j            1.0093           -0.1763
# AR.173            0.4508           +0.9030j            1.0093            0.1763
# AR.174            0.9994           -0.0150j            0.9995           -0.0024
# AR.175            0.9994           +0.0150j            0.9995            0.0024
# AR.176            0.9961           -0.0503j            0.9973           -0.0080
# AR.177            0.9961           +0.0503j            0.9973            0.0080
# AR.178            0.9998           -0.0380j            1.0005           -0.0060
# AR.179            0.9998           +0.0380j            1.0005            0.0060
# AR.180            0.9991           -0.0759j            1.0020           -0.0121
# AR.181            0.9991           +0.0759j            1.0020            0.0121
# AR.236            0.6750           -0.7402j            1.0017           -0.1323
# AR.237            0.6750           +0.7402j            1.0017            0.1323
# AR.238            0.6857           -0.7209j            0.9949           -0.1290
# AR.239            0.6857           +0.7209j            0.9949            0.1290
# AR.240            0.4709           -0.8896j            1.0066           -0.1725
# AR.241            0.4709           +0.8896j            1.0066            0.1725
# AR.242            0.8092           -0.6010j            1.0079           -0.1017
# AR.243            0.8092           +0.6010j            1.0079            0.1017
# AR.244            0.9438           -0.3359j            1.0018           -0.0544
# AR.245            0.9438           +0.3359j            1.0018            0.0544
# AR.246           -1.0002           -0.2005j            1.0200           -0.4685
# AR.247           -1.0002           +0.2005j            1.0200            0.4685
# AR.248            0.5202           -0.8587j            1.0039           -0.1633
# AR.249            0.5202           +0.8587j            1.0039            0.1633
# AR.250            0.9588           -0.2910j            1.0020           -0.0469
# AR.251            0.9588           +0.2910j            1.0020            0.0469
# AR.252            0.7085           -0.7134j            1.0055           -0.1255
# AR.253            0.7085           +0.7134j            1.0055            0.1255
# AR.254            0.7930           -0.6203j            1.0068           -0.1056
# AR.255            0.7930           +0.6203j            1.0068            0.1056
# AR.256            0.7252           -0.6949j            1.0044           -0.1216
# AR.257            0.7252           +0.6949j            1.0044            0.1216
# AR.258            0.7833           -0.6343j            1.0079           -0.1083
# AR.259            0.7833           +0.6343j            1.0079            0.1083
# AR.260           -0.2196           -0.9844j            1.0086           -0.2849
# AR.261           -0.2196           +0.9844j            1.0086            0.2849
# AR.262           -0.9252           -0.4270j            1.0190           -0.4312
# AR.263           -0.9252           +0.4270j            1.0190            0.4312
# AR.264           -0.1882           -0.9868j            1.0046           -0.2800
# AR.265           -0.1882           +0.9868j            1.0046            0.2800
# AR.266            0.7601           -0.6557j            1.0038           -0.1133
# AR.267            0.7601           +0.6557j            1.0038            0.1133
# AR.268            0.9546           -0.3238j            1.0081           -0.0520
# AR.269            0.9546           +0.3238j            1.0081            0.0520
# AR.270           -0.3323           -0.9625j            1.0182           -0.3029
# AR.271           -0.3323           +0.9625j            1.0182            0.3029
# AR.272           -0.2039           -0.9857j            1.0065           -0.2825
# AR.273           -0.2039           +0.9857j            1.0065            0.2825
# AR.274            0.4926           -0.8784j            1.0071           -0.1687
# AR.275            0.4926           +0.8784j            1.0071            0.1687
# AR.276            0.5072           -0.8740j            1.0105           -0.1663
# AR.277            0.5072           +0.8740j            1.0105            0.1663
# AR.278            0.9651           -0.3048j            1.0121           -0.0487
# AR.279            0.9651           +0.3048j            1.0121            0.0487
# AR.280            0.7495           -0.6807j            1.0124           -0.1173
# AR.281            0.7495           +0.6807j            1.0124            0.1173
# AR.282           -0.1753           -1.0024j            1.0176           -0.2775
# AR.283           -0.1753           +1.0024j            1.0176            0.2775
# AR.284           -0.8855           -0.5240j            1.0289           -0.4150
# AR.285           -0.8855           +0.5240j            1.0289            0.4150
# AR.286           -1.0334           -0.0825j            1.0367           -0.4873
# AR.287           -1.0334           +0.0825j            1.0367            0.4873
# AR.288            1.0186           -0.1252j            1.0262           -0.0195
# AR.289            1.0186           +0.1252j            1.0262            0.0195
# AR.290            0.7624           -0.6911j            1.0290           -0.1172
# AR.291            0.7624           +0.6911j            1.0290            0.1172
# AR.292            0.6875           -0.7909j            1.0479           -0.1361
# AR.293            0.6875           +0.7909j            1.0479            0.1361
# AR.294            0.9443           -0.5777j            1.1070           -0.0874
# AR.295            0.9443           +0.5777j            1.1070            0.0874
# AR.296            0.1604           -1.1581j            1.1692           -0.2281
# AR.297            0.1604           +1.1581j            1.1692            0.2281
# AR.298           -0.9131           -1.0006j            1.3546           -0.3677
# AR.299           -0.9131           +1.0006j            1.3546            0.3677
# AR.300           -7.8640           -0.0000j            7.8640           -0.5000
# -------------------------------------------------------------------------------
# Root Mean Square Error: 11885.234793823525
# Mean Square Error:      141258806.1043133
# error %:                btc_p    1.11326
# dtype: float64

# %%
crypto_df
# Out:
#                   btc_p      ltc_p      eth_p     xrp_p    doge_p
# date
# 04/01/2016    426.57000    3.49300     0.9600  0.007418  0.000224
# 06/01/2016    431.32000    3.47900     0.9426  0.005809  0.000234
# 07/01/2016    429.99000    3.44000     0.9500  0.006787  0.000302
# 08/01/2016    457.88354    3.58399     0.9400  0.005906  0.000223
# 11/01/2016    449.13000    3.52817     1.0000  0.008102  0.000221
# ...                 ...        ...        ...       ...       ...
# 20/12/2021  46688.40000  153.22000  3924.3700  0.879828  0.879828
# 21/12/2021  46898.10000  152.75000  3941.8200  0.947646  0.947646
# 22/12/2021  48925.90000  154.70000  4018.2000  0.954699  0.954699
# 23/12/2021  48624.90000  155.41000  3980.4400  0.993285  0.993285
# 29/12/2021  47548.10000  145.64000  3792.0900  0.816714  0.816714
#
# [1287 rows x 5 columns]

# %%
test_btc_r = test_btc.reset_index()

# %%
    # ARIMA 
train_btc = crypto_df['btc_p'][:len(crypto_df)-100]
test_btc = crypto_df['btc_p'][len(crypto_df)-100:]
model = ARIMA(train_btc, order=(100, 2, 2)) 
    # p = number of lag terms taken into account, periods back
    # d = number of times the terms are differenced
    # q = moving average window
model_fit = model.fit()
# predictions_btc = model_fit.predict(len(train_btc)-50, len(test_btc)-1)
predictions_btc = model_fit.predict(len(test_btc)-100, len(test_btc)-1)
    # We convert to DF and reset index to compare with test values 
# predict_btc = pd.DataFrame(predictions_btc)
# predict_btc = predict_btc.reset_index(drop=True)
# predict_btc = predict_btc.rename({'predicted_mean':"predicted"}, axis=1)
#     # make a DF with predictions Vs actual (test) values 
#     # check_gbp = curr_btc[['usd_gbp']].tail(50)
#     # check_gbp = check_gbp.reset_index(drop=True)
# compare_btc_pred = pd.concat([test_btc,predict_btc],axis=1,join="inner",ignore_index=False,sort=False, copy=False) 
# compare_btc_pred['error'] = compare_btc_pred['btc_p'] - compare_btc_pred['predicted']
# compare_btc_pred
    # Model accuracy
MSE_ARIMA_btc = np.square(np.subtract(test_btc,predictions_btc)).mean() 
RMSE_ARIMA_btc = math.sqrt(MSE_ARIMA_btc)
    # Plot the prediction vs test data
plt.plot(test_btc, color= 'blue')
plt.plot(predictions_btc, color='red')

# plt.plot(pred_ar_btc_check)
# plt.plot(result_check_btc, color='red')

print("Root Mean Square Error: ",RMSE_ARIMA_btc)
print("Mean Square Error:      ",MSE_ARIMA_btc)
print("error %:                ",MSE_ARIMA_btc/np.mean(test_btc))
# Out:
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_721/1926232376.py in <module>
#       6 # d = number of times the terms are differenced
#       7 # q = moving average window
# ----> 8 model_fit = model.fit()
#       9 # predictions_btc = model_fit.predict(len(train_btc)-50, len(test_btc)-1)
#      10 predictions_btc = model_fit.predict(len(test_btc)-100, len(test_btc)-1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py in fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     359                 method_kwargs.setdefault('disp', 0)
#     360
# --> 361                 res = super(ARIMA, self).fit(
#     362                     return_params=return_params, low_memory=low_memory,
#     363                     cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     688                 flags['hessian_method'] = optim_hessian
#     689             fargs = (flags,)
# --> 690             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     691                                                fargs=fargs,
#     692                                                maxiter=maxiter,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     517         warn_convergence = kwargs.pop('warn_convergence', True)
#     518         optimizer = Optimizer()
# --> 519         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     520                                                        fargs, kwargs,
#     521                                                        hessian=hess,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     222
#     223         func = fit_funcs[method]
# --> 224         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     225                             disp=disp, maxiter=maxiter, callback=callback,
#     226                             retall=retall, full_output=full_output,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     627         func = f
#     628
# --> 629     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     630                                      callback=callback, args=fargs,
#     631                                      bounds=bounds, disp=disp,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     153                 self._update_fun()
#     154                 self.ngev += 1
# --> 155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                            **finite_diff_options)
#     157
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/opt/anaconda3/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in f(params, *args)
#     499
#     500         def f(params, *args):
# --> 501             return -self.loglike(params, *args) / nobs
#     502
#     503         if method == 'newton':
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     923             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     924
# --> 925         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     926
#     927         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     904
#     905         # Run the filter
# --> 906         kfilter()
#     907
#     908         return kfilter
#
# KeyboardInterrupt:

# %% [markdown]
# # LTC

# %%
# AD FULER TEST FOR STATIONALITY 
stationary_test(crypto_df[['ltc_p']])
# Out:
#  is NOT stationary

# %%
#period=214 shows the 214 days of trade as avreage on records 
rcParams['figure.figsize'] = 18, 8

res = sm.tsa.seasonal_decompose(crypto_df.ltc_p, period=214,model='additive')
print('LTC  mean:' ,crypto_df.ltc_p.mean())
fig = res.plot()
# Out:
# LTC  mean: 76.02117520590517
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_721/1185461715.py in <module>
#       4 res = sm.tsa.seasonal_decompose(crypto_df.ltc_p, period=214,model='additive')
#       5 print('LTC  mean:' ,crypto_df.ltc_p.mean())
# ----> 6 fig = res.plot()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py in plot(self, observed, seasonal, trend, resid, weights)
#     304             ax.set_xlim(xlim)
#     305
# --> 306         fig.tight_layout()
#     307         return fig
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3162                else suppress())
#    3163         with ctx:
# -> 3164             kwargs = get_tight_layout_figure(
#    3165                 self, self.axes, subplotspec_list, renderer,
#    3166                 pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     310                               (colNum2 + 1) * div_col - 1))
#     311
# --> 312     kwargs = auto_adjust_subplotpars(fig, renderer,
#     313                                      nrows_ncols=(max_nrows, max_ncols),
#     314                                      num1num2_list=num1num2_list,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      82             if ax.get_visible():
#      83                 try:
# ---> 84                     bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      85                 except TypeError:
#      86                     bb += [ax.get_tightbbox(renderer)]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4428             if self.xaxis.get_visible():
#    4429                 try:
# -> 4430                     bb_xaxis = self.xaxis.get_tightbbox(
#    4431                         renderer, for_layout_only=for_layout_only)
#    4432                 except TypeError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1084             return
#    1085
# -> 1086         ticks_to_draw = self._update_ticks()
#    1087
#    1088         self._update_label_position(renderer)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1028         major_locs = self.get_majorticklocs()
#    1029         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1030         major_ticks = self.get_major_ticks(len(major_locs))
#    1031         self.major.formatter.set_locs(major_locs)
#    1032         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1357         while len(self.majorTicks) < numticks:
#    1358             # Update the new tick label properties from the old.
# -> 1359             tick = self._get_tick(major=True)
#    1360             self.majorTicks.append(tick)
#    1361             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2057         else:
#    2058             tick_kw = self._minor_tick_kw
# -> 2059         return XTick(self.axes, 0, major=major, **tick_kw)
#    2060
#    2061     def set_label_position(self, position):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     425             marker=self._tickmarkers[0],
#     426         )
# --> 427         self.tick2line.set(
#     428             xdata=[0], ydata=[1],
#     429             transform=self.axes.get_xaxis_transform(which="tick2"),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1152     def set(self, **kwargs):
#    1153         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1154         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1155         move_color_to_start = False
#    1156         if "color" in kwargs:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     404     @functools.wraps(func)
#     405     def wrapper(*inner_args, **inner_kwargs):
# --> 406         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     407         if is_varargs and arguments.get(name):
#     408             warn_deprecated(
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7fc5d445e8b0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in _fetch_figure_metadata(fig)
#     229     if _is_transparent(fig.get_facecolor()):
#     230         # the background is transparent
# --> 231         ticksLight = _is_light([label.get_color()
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib_inline/backend_inline.py in <listcomp>(.0)
#     232                                 for axes in fig.axes
#     233                                 for axis in (axes.xaxis, axes.yaxis)
# --> 234                                 for label in axis.get_ticklabels()])
#     235         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     236             # there are one or more tick labels, all with the same lightness
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1230         if minor:
#    1231             return self.get_minorticklabels()
# -> 1232         return self.get_majorticklabels()
#    1233
#    1234     def get_majorticklines(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1182     def get_majorticklabels(self):
#    1183         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1184         ticks = self.get_major_ticks()
#    1185         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1186         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1357         while len(self.majorTicks) < numticks:
#    1358             # Update the new tick label properties from the old.
# -> 1359             tick = self._get_tick(major=True)
#    1360             self.majorTicks.append(tick)
#    1361             self._copy_tick_props(self.majorTicks[0], tick)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2057         else:
#    2058             tick_kw = self._minor_tick_kw
# -> 2059         return XTick(self.axes, 0, major=major, **tick_kw)
#    2060
#    2061     def set_label_position(self, position):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#     418
#     419     def __init__(self, *args, **kwargs):
# --> 420         super().__init__(*args, **kwargs)
#     421         # x in data coords, y in axes coords
#     422         self.tick1line.set(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     161             markeredgecolor=color, markersize=size, markeredgewidth=width,
#     162         )
# --> 163         self.gridline = mlines.Line2D(
#     164             [], [],
#     165             color=grid_color, alpha=grid_alpha, visible=gridOn,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     308
#     309         """
# --> 310         super().__init__()
#     311
#     312         #convert sequences to numpy arrays
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in __init__(self)
#     119         # only if they override get_cursor_data.
#     120         self._mouseover = type(self).get_cursor_data != Artist.get_cursor_data
# --> 121         self._callbacks = cbook.CallbackRegistry()
#     122         try:
#     123             self.axes = None
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in __init__(self, exception_handler)
#     169
#     170     def __init__(self, exception_handler=_exception_printer):
# --> 171         self.exception_handler = exception_handler
#     172         self.callbacks = {}
#     173         self._cid_gen = itertools.count()
#
# KeyboardInterrupt:

# %%
# AUTOREGRESSION MODEL:
    # Train Test Split
train_ltc = crypto_df['ltc_p'][:len(crypto_df)-100]
test_ltc = crypto_df['ltc_p'][len(crypto_df)-100:]
    # Instantiate and fit the AR model with training data
ar_ltc = AutoReg(train_ltc, lags=300).fit()
    # Make the predictions
pred_ar_ltc = ar_ltc.predict(start=len(train_ltc), end=(len(crypto_df)-1), dynamic=False)
print(ar_ltc.summary())
    # Accuracy
MSE_AR_ltc = mean_squared_error(test_ltc, pred_ar_ltc)
RMSE_AR_ltc = math.sqrt(MSE_AR_ltc)
pred_ar_ltc_check = pred_ar_ltc.reset_index(drop=True)
    # Plot the prediction vs test data
plt.plot(pred_ar_ltc, color='red')
plt.plot(test_ltc, color='blue')

print("Root Mean Square Error:", RMSE_AR_ltc)
print("Mean Square Error:     ",MSE_AR_ltc)
print("error %:               " , RMSE_AR_ltc/np.mean(test_ltc))

# %% [markdown]
# # ETH

# %%
# AD FULER TEST FOR STATIONALITY 
stationary_test(crypto_df[['eth_p']])
# Out:
#  is NOT stationary

# %%
# # Check features for Seasonality with the complete DF curr_btc:

#period=214 shows the 214 days of trade as avreage on records 
rcParams['figure.figsize'] = 18, 8

res = sm.tsa.seasonal_decompose(crypto_df.eth_p, period=214,model='additive') 
print('ETH  mean:' ,crypto_df.eth_p.mean())
fig = res.plot()
# Out:
# ETH  mean: 630.9027437218336
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_721/218639261.py in <module>
#       6 res = sm.tsa.seasonal_decompose(crypto_df.eth_p, period=214,model='additive')
#       7 print('ETH  mean:' ,crypto_df.eth_p.mean())
# ----> 8 fig = res.plot()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py in plot(self, observed, seasonal, trend, resid, weights)
#     290             xlim = (0, self._observed.shape[0] - 1)
#     291
# --> 292         fig, axs = plt.subplots(len(series), 1)
#     293         for i, (ax, (series, def_name)) in enumerate(zip(axs, series)):
#     294             if def_name != 'residual':
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1438     """
#    1439     fig = figure(**fig_kw)
# -> 1440     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1441                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1442                        gridspec_kw=gridspec_kw)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     909             gridspec_kw = {}
#     910         gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 911         axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     912                           subplot_kw=subplot_kw)
#     913         return axs
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     305                 subplot_kw["sharex"] = shared_with[sharex]
#     306                 subplot_kw["sharey"] = shared_with[sharey]
# --> 307                 axarr[row, col] = figure.add_subplot(
#     308                     self[row, col], **subplot_kw)
#     309
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     782             projection_class, pkw = self._process_projection_requirements(
#     783                 *args, **kwargs)
# --> 784             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     785             key = (projection_class, pkw)
#     786         return self._add_axes_internal(ax, key)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      34         """
#      35         # _axes_class is set in the subplot_class_factory
# ---> 36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
#      38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     624
#     625         # this call may differ for non-sep axes, e.g., polar
# --> 626         self._init_axis()
#     627         if facecolor is None:
#     628             facecolor = mpl.rcParams['axes.facecolor']
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _init_axis(self)
#     742     def _init_axis(self):
#     743         # This is moved out of __init__ because non-separable axes don't use it
# --> 744         self.xaxis = maxis.XAxis(self)
#     745         self.spines.bottom.register_axis(self.xaxis)
#     746         self.spines.top.register_axis(self.xaxis)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, *args, **kwargs)
#    2014
#    2015     def __init__(self, *args, **kwargs):
# -> 2016         super().__init__(*args, **kwargs)
#    2017         # x in axes coords, y in display coords (to be updated at draw time by
#    2018         # _update_label_positions and _update_offset_text_position).
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in __init__(self, axes, pickradius)
#     693         self._minor_tick_kw = dict()
#     694
# --> 695         self.clear()
#     696         self._set_scale('linear')
#     697
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in clear(self)
#     787         self.label.set_text('')  # self.set_label_text would change isDefault_
#     788
# --> 789         self._set_scale('linear')
#     790
#     791         # Clear the callback registry for this axis, or it may "leak"
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     745         else:
#     746             self._scale = value
# --> 747         self._scale.set_default_locators_and_formatters(self)
#     748
#     749         self.isDefault_majloc = True
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/scale.py in set_default_locators_and_formatters(self, axis)
#      96     def set_default_locators_and_formatters(self, axis):
#      97         # docstring inherited
# ---> 98         axis.set_major_locator(AutoLocator())
#      99         axis.set_major_formatter(ScalarFormatter())
#     100         axis.set_minor_formatter(NullFormatter())
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/ticker.py in __init__(self)
#    2899             nbins = 'auto'
#    2900             steps = [1, 2, 2.5, 5, 10]
# -> 2901         super().__init__(nbins=nbins, steps=steps)
#    2902
#    2903
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/ticker.py in __init__(self, *args, **kwargs)
#    2132                 raise ValueError(
#    2133                     "Keywords are required for all arguments except 'nbins'")
# -> 2134         self.set_params(**{**self.default_params, **kwargs})
#    2135
#    2136     @staticmethod
#
# KeyboardInterrupt:

# %%
# AUTOREGRESSION MODEL:
    # Train Test Split
train_eth = crypto_df['eth_p'][:len(crypto_df)-100]
test_eth = crypto_df['eth_p'][len(crypto_df)-100:]
    # Instantiate and fit the AR model with training data
ar_btc = AutoReg(train_btc, lags=300).fit()
    # Make the predictions
pred_ar_btc = ar_btc.predict(start=len(train_btc), end=(len(crypto_df)-1), dynamic=False)
print(ar_model.summary())
    # Accuracy
MSE_AR_btc = mean_squared_error(test_btc, pred_ar_btc)
RMSE_AR_btc = math.sqrt(MSE_AR_btc)
pred_ar_btc_check = pred_ar_btc.reset_index(drop=True)
result_check_btc
    # Plot the prediction vs test data
plt.plot(pred_ar_btc_check, color='red')
plt.plot(result_check_btc, color='blue')

print("Root Mean Square Error:", RMSE_AR_btc)
print("Mean Square Error:     ",MSE_AR_btc)
print("error %:               " , RMSE_AR_btc/np.mean(btc_test))

# %% [markdown]
# # XRP

# %%
# AD FULER TEST FOR STATIONALITY 
stationary_test(crypto_df[['xrp_p']])
# Out:
#  is NOT stationary

# %%
# # Check features for Seasonality with the complete DF curr_btc:
#period=214 shows the 214 days of trade as avreage on records 
rcParams['figure.figsize'] = 18, 8
res = sm.tsa.seasonal_decompose(crypto_df.xrp_p, period=214,model='additive') 
print('XRP  mean:' ,crypto_df.xrp_p.mean())
fig = res.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_721/1524957572.py in <module>
#       2 #period=214 shows the 214 days of trade as avreage on records
#       3 rcParams['figure.figsize'] = 18, 8
# ----> 4 res = sm.tsa.seasonal_decompose(crypto_df.xrp_p, period=214,model='additive')
#       5 print('XRP  mean:' ,crypto_df.xrp_p.mean())
#       6 fig = res.plot()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     169         detrended = x - trend
#     170
# --> 171     period_averages = seasonal_mean(detrended, period)
#     172
#     173     if model.startswith('m'):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py in seasonal_mean(x, period)
#      54     in the mean.
#      55     """
# ---> 56     return np.array([pd_nanmean(x[i::period], axis=0) for i in range(period)])
#      57
#      58
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/seasonal.py in <listcomp>(.0)
#      54     in the mean.
#      55     """
# ---> 56     return np.array([pd_nanmean(x[i::period], axis=0) for i in range(period)])
#      57
#      58
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     144                     #  TypeError if called
#     145                     kwds.pop("mask", None)
# --> 146                     result = bn_func(values, axis=axis, **kwds)
#     147
#     148                     # prefer to treat inf/-inf as NA, but must compute the func
#
# KeyboardInterrupt:

# %%
# AUTOREGRESSION MODEL:
    # Train Test Split
train_xrp = crypto_df['xrp_p'][:len(crypto_df)-100]
test_xrp = crypto_df['xrp_p'][len(crypto_df)-100:]
    # Instantiate and fit the AR model with training data
ar_btc = AutoReg(train_xrp, lags=300).fit()
    # Make the predictions
pred_ar_btc = ar_btc.predict(start=len(train_btc), end=(len(crypto_df)-1), dynamic=False)
print(ar_model.summary())
    # Accuracy
MSE_AR_btc = mean_squared_error(test_btc, pred_ar_btc)
RMSE_AR_btc = math.sqrt(MSE_AR_btc)
pred_ar_btc_check = pred_ar_btc.reset_index(drop=True)
result_check_btc
    # Plot the prediction vs test data
plt.plot(pred_ar_btc_check, color='red')
plt.plot(result_check_btc, color='blue')

print("Root Mean Square Error:", RMSE_AR_btc)
print("Mean Square Error:     ",MSE_AR_btc)
print("error %:               " , RMSE_AR_btc/np.mean(btc_test))

# %% [markdown]
# # DOGE

# %%
# AD FULER TEST FOR STATIONALITY 
stationary_test(crypto_df[['doge_p']])

# %%
# # Check features for Seasonality with the complete DF curr_btc:
#period=214 shows the 214 days of trade as avreage on records 
rcParams['figure.figsize'] = 18, 8

res = sm.tsa.seasonal_decompose(crypto_df.doge_p, period=214,model='additive') 
print('DOGE mean:' ,crypto_df.doge_p.mean())
fig = res.plot()

# %%
# AUTOREGRESSION MODEL:
    # Train Test Split
train_btc = crypto_df['btc_p'][:len(crypto_df)-100]
test_btc = crypto_df['btc_p'][len(crypto_df)-100:]
    # Instantiate and fit the AR model with training data
ar_btc = AutoReg(train_data, lags=300).fit()
    # Make the predictions
pred_ar_btc = ar_btc.predict(start=len(train_btc), end=(len(crypto_df)-1), dynamic=False)
print(ar_model.summary())
    # Accuracy
MSE_AR_btc = mean_squared_error(test_btc, pred_ar_btc)
RMSE_AR_btc = math.sqrt(MSE_AR_btc)
pred_ar_btc_check = pred_ar_btc.reset_index(drop=True)
result_check_btc
    # Plot the prediction vs test data
plt.plot(pred_ar_btc_check, color='red')
plt.plot(result_check_btc, color='blue')

print("Root Mean Square Error:", RMSE_AR_btc)
print("Mean Square Error:     ",MSE_AR_btc)
print("error %:               " , RMSE_AR_btc/np.mean(btc_test))
