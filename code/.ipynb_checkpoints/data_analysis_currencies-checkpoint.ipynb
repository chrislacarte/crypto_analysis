# %% [markdown]
# # CURRENCIES Vs CRYPTO

# %% [markdown]
# # DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import itertools
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import statsmodels.api as sm
from sklearn.neighbors import KNeighborsRegressor
from pandas.plotting import lag_plot
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
from pylab import rcParams
# import fbprophet

# %%
# Load the data 
main_df = pd.read_csv("../final_data/final_df.csv")
# crypto_df = pd.read_csv("../final_data/crypto_series.csv")
# currency_df = pd.read_csv("../final_data/currency_series.csv")
# commodity_df = pd.read_csv("../final_data/commodity_series.csv")
# rates_df = pd.read_csv("../final_data/rates_series.csv")

# %%
# Set datetime index in all DFs:
main_df = main_df.set_index('date')
# crypto_df = crypto_df.set_index('date')
# currency_df = currency_df.set_index('date')
# commodity_df = commodity_df.set_index('date')
# rates_df = rates_df.set_index('date')

# %%
# # Defining which columns belong to every group of features
# crypto_col = ['btc_p', 'ltc_p', 'eth_p', 'xrp_p', 'doge_p']
# currency_col = ['usd_gbp', 'usd_gbp_ %','usd_eur', 'usd_eur_%', 'usd_yuan', 'usd_yuan_%', 'usd_yen','usd_yen_ %'] 
# comm_col = ['wti_oil_pprice', 'brent_oil_p', 'gold_p', 'silver_p','steel_price']
# rates_col = ['LIBOR', 'eonia', 'fed_rate']

# # Separarting DF for further analysis
# crypto = main_df[crypto_col]
# currency = main_df[currency_col]
# commodity = main_df[comm_col]
# rates = main_df[rates_col]

# %%
main_df
# Out:
#                   btc_p      ltc_p      eth_p     xrp_p    doge_p  usd_gbp  \
# date
# 04/01/2016    426.57000    3.49300     0.9600  0.007418  0.000224   0.6794
# 06/01/2016    431.32000    3.47900     0.9426  0.005809  0.000234   0.6836
# 07/01/2016    429.99000    3.44000     0.9500  0.006787  0.000302   0.6841
# 08/01/2016    457.88354    3.58399     0.9400  0.005906  0.000223   0.6887
# 11/01/2016    449.13000    3.52817     1.0000  0.008102  0.000221   0.6876
# ...                 ...        ...        ...       ...       ...      ...
# 20/12/2021  46688.40000  153.22000  3924.3700  0.879828  0.879828   0.7571
# 21/12/2021  46898.10000  152.75000  3941.8200  0.947646  0.947646   0.7535
# 22/12/2021  48925.90000  154.70000  4018.2000  0.954699  0.954699   0.7488
# 23/12/2021  48624.90000  155.41000  3980.4400  0.993285  0.993285   0.7457
# 29/12/2021  47548.10000  145.64000  3792.0900  0.816714  0.816714   0.7412
#
#            usd_gbp_ %  usd_eur usd_eur_%  usd_yuan  ... usd_yen  usd_yen_ %  \
# date                                                ...
# 04/01/2016      0.19%   0.9232     0.26%    6.5354  ...  119.44      -0.74%
# 06/01/2016      0.31%   0.9275    -0.31%    6.5566  ...  118.47      -0.50%
# 07/01/2016      0.07%   0.9144    -1.41%    6.5929  ...  117.68      -0.67%
# 08/01/2016      0.67%   0.9148     0.04%    6.5965  ...  117.45      -0.20%
# 11/01/2016     -0.16%   0.9208     0.66%    6.5695  ...  117.77       0.27%
# ...               ...      ...       ...       ...  ...     ...         ...
# 20/12/2021      0.25%   0.8866    -0.33%    6.3756  ...  113.58      -0.08%
# 21/12/2021     -0.48%   0.8860    -0.07%    6.3716  ...  114.08       0.44%
# 22/12/2021     -0.62%   0.8828    -0.36%    6.3695  ...  114.11       0.03%
# 23/12/2021     -0.41%   0.8826    -0.02%    6.3696  ...  114.37       0.23%
# 29/12/2021     -0.40%   0.8809    -0.34%    6.3680  ...  114.94       0.11%
#
#            wti_oil_pprice  brent_oil_p  gold_p  silver_p  steel_price  \
# date
# 04/01/2016          36.81        37.22  1075.2   13.8400       0.7704
# 06/01/2016          33.97        34.23  1091.9   13.9800       0.7154
# 07/01/2016          33.29        33.75  1107.8   14.3400       0.6355
# 08/01/2016          33.20        33.55  1097.9   13.9200       0.6398
# 11/01/2016          31.42        31.55  1096.2   13.8700       0.6573
# ...                   ...          ...     ...       ...          ...
# 20/12/2021          68.69        70.51  1794.6   22.2700       3.8972
# 21/12/2021          71.10        72.85  1788.7   22.4940       4.0883
# 22/12/2021          72.82        74.69  1802.2   22.7860       4.1265
# 23/12/2021          73.89        76.26  1811.7   22.9130       4.1169
# 29/12/2021          76.58        78.63  1805.8   22.8394       4.1360
#
#               LIBOR  eonia  fed_rate
# date
# 04/01/2016  0.37910 -0.335      0.37
# 06/01/2016  0.38550 -0.333      0.37
# 07/01/2016  0.40610 -0.321      0.41
# 08/01/2016  0.41440 -0.330      0.40
# 11/01/2016  0.43456 -0.348      0.41
# ...             ...    ...       ...
# 20/12/2021  0.07250 -0.491      0.08
# 21/12/2021  0.07288 -0.486      0.08
# 22/12/2021  0.07050 -0.489      0.08
# 23/12/2021  0.07513 -0.491      0.08
# 29/12/2021  0.07275 -0.493      0.08
#
# [1287 rows x 21 columns]

# %% [markdown]
# The crypto DF does not need transformation for now as will be the target.

# %%
# CURRENCY PRICES IN $ Vs CRYPTO PRICES 
curr_btc = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','btc_p']]
curr_ltc = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','ltc_p']]
curr_eth = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','eth_p']]
curr_xrp = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','xrp_p']]
curr_doge= main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','doge_p']]

# CURRENCY PRICE VARIATION Vs CRYPTO PRICES 
curr_var_btc = main_df[['usd_gbp_ %','usd_eur_%','usd_yuan_%','usd_yen_ %','btc_p']]
curr_var_ltc = main_df[['usd_gbp_ %','usd_eur_%','usd_yuan_%','usd_yen_ %','ltc_p']]
curr_var_eth = main_df[['usd_gbp_ %','usd_eur_%','usd_yuan_%','usd_yen_ %','eth_p']]
curr_var_xrp = main_df[['usd_gbp_ %','usd_eur_%','usd_yuan_%','usd_yen_ %','xrp_p']]
curr_var_doge= main_df[['usd_gbp_ %','usd_eur_%','usd_yuan_%','usd_yen_ %','doge_p']]

# COMMODITY PRICES Vs CRYPTO PRICES 
comm_btc = main_df[['wti_oil_pprice', 'brent_oil_p', 'gold_p', 'silver_p', 'steel_price', 'btc_p']]
comm_ltc = main_df[['wti_oil_pprice', 'brent_oil_p', 'gold_p', 'silver_p', 'steel_price', 'ltc_p']]
comm_eth = main_df[['wti_oil_pprice', 'brent_oil_p', 'gold_p', 'silver_p', 'steel_price', 'eth_p']]
comm_xrp = main_df[['wti_oil_pprice', 'brent_oil_p', 'gold_p', 'silver_p', 'steel_price', 'xrp_p']]
comm_doge= main_df[['wti_oil_pprice', 'brent_oil_p', 'gold_p', 'silver_p', 'steel_price', 'doge_p']]

# INTEREST RATES Vs CRYPTO PRICES 
rates_btc = main_df[['LIBOR', 'eonia', 'fed_rate', 'btc_p']]
rates_ltc = main_df[['LIBOR', 'eonia', 'fed_rate', 'ltc_p']]
rates_eth = main_df[['LIBOR', 'eonia', 'fed_rate', 'eth_p']]
rates_xrp = main_df[['LIBOR', 'eonia', 'fed_rate', 'xrp_p']]
rates_doge= main_df[['LIBOR', 'eonia', 'fed_rate', 'doge_p']]

# %% [markdown]
# # DESCRIPTIVE ANALYSIS

# %% [markdown]
# CURRENCY PRICES (in $) Vs CRYPTO PRICES

# %%
curr_btc = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','btc_p']]
curr_ltc = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','ltc_p']]
curr_eth = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','eth_p']]
curr_xrp = main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','xrp_p']]
curr_doge= main_df[['usd_gbp', 'usd_eur', 'usd_yuan',  'usd_yen','doge_p']]

# %%
# Standardize
scaler_1 = MinMaxScaler()
curr_btc__ = scaler_1.fit_transform(curr_btc)
curr_ltc__ = scaler_1.fit_transform(curr_ltc)
curr_eth__ = scaler_1.fit_transform(curr_eth)
curr_xrp__ = scaler_1.fit_transform(curr_xrp)
curr_doge__ = scaler_1.fit_transform(curr_doge)

# Convert to DF
curr_btc__ = pd.DataFrame(curr_btc__, columns=curr_btc.columns)
curr_ltc__ = pd.DataFrame(curr_ltc__, columns=curr_ltc.columns)
curr_eth__ = pd.DataFrame(curr_eth__, columns=curr_eth.columns)
curr_xrp__ = pd.DataFrame(curr_xrp__, columns=curr_xrp.columns)
curr_doge__= pd.DataFrame(curr_doge__, columns=curr_doge.columns)

# %% [markdown]
# I have to scale and normalize

# %%
# #Check multicolinearity:
# correlations_matrix = curr_btc.corr()
# correlations_matrix

# sns.heatmap(correlations_matrix, annot=True)
# plt.show()

# %%
#######################################
# BTC Vs USD-GBP correlation : -0.36
# BTC Vs USD-EUR correlation : -0.45
# BTC Vs USD-YUAN correlation : -0.46
# BTC Vs USD-YEN correlation : 0.013
# The Yen price has very little correlation, with bitcoin price. I am going to leave it out of the analysis.
#######################################

# %%
# Drop "usd_yen" :
curr_btc = curr_btc.drop("usd_yen",axis=1)

# %% [markdown]
# There are some relevant relations between the target (btc_p) and the features, although there migth be exponential correlation

# %%
# # Let's plot the features to visually inspect them.

# # All currencies prices Vs BTC price 

#     # Scatter plots 
# plt.scatter(x=curr_btc['usd_gbp'], y=curr_btc['btc_p'])
# plt.title("GBP/BTC")
# plt.show()
# plt.scatter(x=curr_btc['usd_eur'], y=curr_btc['btc_p'])
# plt.title("EUR/BTC")
# plt.show()
# plt.scatter(x=curr_btc['usd_yuan'], y=curr_btc['btc_p'])
# plt.title("YUAN/BTC")
# plt.show()

#     # All values distributions 
# sns.displot(curr_btc['usd_gbp'])
# plt.title("GBP")
# plt.show()
# sns.displot(curr_btc['usd_eur'])
# plt.title("EUR")
# plt.show()
# sns.displot(curr_btc['usd_yuan'])
# plt.title("YUAN")
# plt.show()
# sns.displot(curr_btc['btc_p'])
# plt.title("BTC")
# plt.show()
    
#     # Boxplots (Individually plotted)
# curr_btc[['usd_gbp']].boxplot()
# plt.title("USD/GBP")
# plt.show()
# curr_btc[['usd_eur']].boxplot()
# plt.title("USD/EUR")
# plt.show()
# curr_btc[['usd_yuan']].boxplot()
# plt.title("USD/YUAN")
# plt.show()
# curr_btc[['btc_p']].boxplot()
# plt.title("BTC")
# plt.show()

# %%
# # X and Y split 
# y = curr_btc['btc_p']
# X = curr_btc.drop(['btc_p'], axis=1)
# lm = linear_model.LinearRegression()
# lm.fit(X,y)
# print("R2-score is:",lm.score(X,y))
# y_pred=lm.predict(X)
# print("MSE is :",mean_squared_error(y_pred,y))
# R2-score is: 0.25169277516874844
# MSE is : 190782489.03306693

# %% [markdown]
# # curr_btc_gbp_s = curr_btc ['usd_gbp']

# %%
# X and Y split 
X_curr = curr_btc.drop(['btc_p'], axis=1)
y_curr = curr_btc[['btc_p']]

#TRAIN TEST SPLIT 
X_curr_train, X_curr_test, y_curr_train, y_curr_test = train_test_split(
    X_curr, y_curr,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# There are hints of inverse function ( y = |1/x| ) type of regression. We will see which model predicts better.
#
# They are all of them quite Normally distributed, I will keep outliers as they are relevant (prices)
#
# I am applying MinMaxScaler due to:
# Preserves the shape of the original distribution.
# It doesn’t meaningfully change the information embedded in the original data.
# Doesn’t reduce the importance of outliers.
# Default range for the feature returned by MinMaxScaler is 0 to 1.
# Also the variables are quite Normally distibuted already

# %%
# Standardize
scaler = MinMaxScaler()
X_curr_train_sc = scaler.fit_transform(X_curr_train)
X_curr_test_sc  = scaler.transform(X_curr_test)

# Convert to DF
X_curr_tr = pd.DataFrame(X_curr_train_sc, columns=X_curr_train.columns)
X_curr_te = pd.DataFrame(X_curr_test_sc, columns=X_curr_test.columns)

# %% [markdown]
# Model selection: Which model will predict more accurately?
# Most likely linear models will not work well as the data sugest Logaritmic regression line
#     I am going to try:
#
#         Linear Regression
#
#         KNN Regression Model

# %%
#Linear Regression

lm = linear_model.LinearRegression()
lm.fit(X_curr_train,y_curr_train)
print('lm Itercept:' , lm.intercept_) #b(0)
print('lm coef:' ,lm.coef_) #b(1) coefficients is an array because we can have more than one dimension for our gradient
y_pred = lm.predict(X_curr_test)
MSE_lin = np.square(np.subtract(y_curr_test,y_pred)).mean() 
RMSE_lin = math.sqrt(MSE_lin)
print("Root Mean Square Error: " ,MSE_lin)
print("Mean Square Error:      " ,RMSE_lin)
# Very bad predictions
# Out:
# lm Itercept: [215566.97243733]
# lm coef: [[  48545.34290377 -150084.1050535   -22403.73225866     382.97856231]]
# Root Mean Square Error:  btc_p    2.278780e+08
# dtype: float64
# Mean Square Error:       15095.627944991076

# %%
# Plot the data to visually inspect 
plt.scatter(X_curr_train['usd_gbp'], y_curr_train)
plt.plot(X_curr_train['usd_gbp'], y_curr_train, color='red')
plt.show()
# NO linear dependency

# %%
predictions_test = lm.predict(X_curr_train)
r2_score(y_curr_train, predictions_test)

# Not following a linear finction on the regression
# OUTPUT r2_score = 0.24764100302924907
# Out:
# 0.2640468876076123

# %%
# KNN 
# 5 neighbors

KNN = KNeighborsRegressor(n_neighbors=5)
KNN.fit(X_curr_train, y_curr_train)

score = KNN.score(X_curr_test, y_curr_test)
score
# 0.5690078560029692
# The result is not very good,....confirms it doesn't really make sense as is a timeseries
# Out:
# 0.5690078560029692

# %%
#######################################
# The data's regression line doesn't follow a linear function, I need to find a regression method that 
#  follows y = 1/X regression line 
# Or create a collumn woth the inverse functions of the columns and do a linear regression 
# 
# 
#######################################

# %%
curr_btc
# Out:
#             usd_gbp  usd_eur  usd_yuan        btc_p
# date
# 04/01/2016   0.6794   0.9232    6.5354    426.57000
# 06/01/2016   0.6836   0.9275    6.5566    431.32000
# 07/01/2016   0.6841   0.9144    6.5929    429.99000
# 08/01/2016   0.6887   0.9148    6.5965    457.88354
# 11/01/2016   0.6876   0.9208    6.5695    449.13000
# ...             ...      ...       ...          ...
# 20/12/2021   0.7571   0.8866    6.3756  46688.40000
# 21/12/2021   0.7535   0.8860    6.3716  46898.10000
# 22/12/2021   0.7488   0.8828    6.3695  48925.90000
# 23/12/2021   0.7457   0.8826    6.3696  48624.90000
# 29/12/2021   0.7412   0.8809    6.3680  47548.10000
#
# [1287 rows x 4 columns]

# %% [markdown]
# Create a 1/x DF PRIVED TO BE IRRELEVANT

# %% [markdown]
# # TIME SERIES ANALYSIS

# %%
# # Check features for Seasonality with the complete DF curr_btc

# Standardize
scaler = MinMaxScaler()
curr_btc_sc = scaler.fit_transform(curr_btc)

# Convert to DF
curr_btc_s = pd.DataFrame(curr_btc_sc, columns=curr_btc.columns)


#period=214 shows the 214 days of trade as avreage on records 
rcParams['figure.figsize'] = 18, 8

res = sm.tsa.seasonal_decompose(curr_btc_s.usd_gbp, period=214,model='additive')  
print('USD/GBP  mean:' ,curr_btc_s.usd_gbp.mean())
fig = res.plot()

res = sm.tsa.seasonal_decompose(curr_btc_s.usd_eur, period=214,model='additive')
print('USD/EUR  mean:' ,curr_btc_s.usd_eur.mean())
fig = res.plot()

res = sm.tsa.seasonal_decompose(curr_btc_s.usd_eur, period=214,model='additive') 
print('USD/YUAN mean:' ,curr_btc_s.usd_eur.mean())
fig = res.plot()

res = sm.tsa.seasonal_decompose(curr_btc_s.btc_p, period=214,model='additive') 
print('BTC      mean:' ,curr_btc_s.btc_p.mean())
fig = res.plot()
# Out:
# USD/GBP  mean: 0.44328932679916105
# USD/EUR  mean: 0.46931988879325
# USD/YUAN mean: 0.46931988879325
# BTC      mean: 0.18836250567688476

# %% [markdown]
# We can cconclude that nor the currencies or BTC follow any significant seasonality.
#
# The Seasonal Descomposer has found patterns lets say woth a 10% var range,  but then the errors where 25% range>

# %%
lag_plot(curr_btc_s.usd_gbp) 
plt.show()
lag_plot(curr_btc_s.usd_eur)
plt.show()
lag_plot(curr_btc_s.usd_yuan) 
plt.show()
lag_plot(curr_btc_s.btc_p) 
plt.show()

# %%
#########################################################################################
# STRONG AUTOCORRELATION (The value for period 't' is strongly dependent from value (t-1))
# There is a break n the plot on BTC due t big fluctuations (EMOTION RESPONSE ? )
#########################################################################################

# %%
#reset index
# curr_btc = curr_btc.reset_index()

# Sacaling before tiemnseries analysis 
scaler = MinMaxScaler()
curr_btc_scal = scaler.fit_transform(curr_btc)
curr_btc_s = pd.DataFrame(curr_btc_scal, columns=curr_btc.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_33336/3226925014.py in <module>
#       4 # Sacaling before tiemnseries analysis
#       5 scaler = MinMaxScaler()
# ----> 6 curr_btc_scal = scaler.fit_transform(curr_btc)
#       7 curr_btc_s = pd.DataFrame(curr_btc_scal, columns=curr_btc.columns)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     865         if y is None:
#     866             # fit method of arity 1 (unsupervised transformation)
# --> 867             return self.fit(X, **fit_params).transform(X)
#     868         else:
#     869             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     418         # Reset internal state before fitting
#     419         self._reset()
# --> 420         return self.partial_fit(X, y)
#     421
#     422     def partial_fit(self, X, y=None):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     455
#     456         first_pass = not hasattr(self, "n_samples_seen_")
# --> 457         X = self._validate_data(
#     458             X,
#     459             reset=first_pass,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     575             raise ValueError("Validation should be done on X, y or both.")
#     576         elif not no_val_X and no_val_y:
# --> 577             X = check_array(X, input_name="X", **check_params)
#     578             out = X
#     579         elif no_val_X and not no_val_y:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     854                     array = array.astype(dtype, casting="unsafe", copy=False)
#     855                 else:
# --> 856                     array = np.asarray(array, order=order, dtype=dtype)
#     857             except ComplexWarning as complex_warning:
#     858                 raise ValueError(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: '04/01/2016'

# %%
curr_btc
# Out:
#             date  usd_gbp  usd_eur  usd_yuan  usd_yen        btc_p
# 0     04/01/2016   0.6794   0.9232    6.5354   119.44    426.57000
# 1     06/01/2016   0.6836   0.9275    6.5566   118.47    431.32000
# 2     07/01/2016   0.6841   0.9144    6.5929   117.68    429.99000
# 3     08/01/2016   0.6887   0.9148    6.5965   117.45    457.88354
# 4     11/01/2016   0.6876   0.9208    6.5695   117.77    449.13000
# ...          ...      ...      ...       ...      ...          ...
# 1282  20/12/2021   0.7571   0.8866    6.3756   113.58  46688.40000
# 1283  21/12/2021   0.7535   0.8860    6.3716   114.08  46898.10000
# 1284  22/12/2021   0.7488   0.8828    6.3695   114.11  48925.90000
# 1285  23/12/2021   0.7457   0.8826    6.3696   114.37  48624.90000
# 1286  29/12/2021   0.7412   0.8809    6.3680   114.94  47548.10000
#
# [1287 rows x 6 columns]

# %%
curr_btc_s
# Out:
#        usd_gbp   usd_eur  usd_yuan   usd_yen     btc_p
# 0     0.036813  0.758114  0.295983  0.923477  0.006460
# 1     0.057993  0.784446  0.319573  0.877657  0.006532
# 2     0.060514  0.704225  0.359964  0.840340  0.006511
# 3     0.083712  0.706675  0.363970  0.829476  0.006934
# 4     0.078164  0.743417  0.333927  0.844591  0.006801
# ...        ...       ...       ...       ...       ...
# 1282  0.428643  0.533987  0.118171  0.646670  0.707016
# 1283  0.410489  0.530312  0.113720  0.670288  0.710192
# 1284  0.386788  0.510716  0.111383  0.671705  0.740900
# 1285  0.371155  0.509492  0.111494  0.683987  0.736341
# 1286  0.348462  0.499081  0.109714  0.710912  0.720035
#
# [1287 rows x 5 columns]

# %%
# # Train test per currency, and BTC sperately (we are predicting each one separately)

#  USD / GBP 
gbp_train, gbp_test = curr_btc["usd_gbp"][:-50], curr_btc["usd_gbp"][-50:]


# Convert to DF
gbp_train = pd.DataFrame(gbp_train)
gbp_test = pd.DataFrame(gbp_test)

# %%
# Out:
#             usd_gbp
# date
# 29/09/2021   0.7445
# 30/09/2021   0.7421
# 08/10/2021   0.7345
# 11/10/2021   0.7354
# 12/10/2021   0.7358
# 13/10/2021   0.7320
# 14/10/2021   0.7312
# 15/10/2021   0.7271
# 18/10/2021   0.7284
# 19/10/2021   0.7247
# 20/10/2021   0.7233
# 21/10/2021   0.7249
# 22/10/2021   0.7270
# 25/10/2021   0.7262
# 26/10/2021   0.7262
# 27/10/2021   0.7272
# 28/10/2021   0.7251
# 29/10/2021   0.7302
# 01/11/2021   0.7317
# 02/11/2021   0.7343
# 03/11/2021   0.7306
# 05/11/2021   0.7407
# 08/11/2021   0.7373
# 15/11/2021   0.7450
# 16/11/2021   0.7445
# 17/11/2021   0.7416
# 18/11/2021   0.7410
# 19/11/2021   0.7432
# 22/11/2021   0.7464
# 23/11/2021   0.7473
# 24/11/2021   0.7501
# 26/11/2021   0.7496
# 29/11/2021   0.7510
# 30/11/2021   0.7518
# 01/12/2021   0.7529
# 02/12/2021   0.7513
# 03/12/2021   0.7556
# 07/12/2021   0.7549
# 08/12/2021   0.7568
# 10/12/2021   0.7533
# 13/12/2021   0.7564
# 14/12/2021   0.7552
# 15/12/2021   0.7538
# 16/12/2021   0.7506
# 17/12/2021   0.7552
# 20/12/2021   0.7571
# 21/12/2021   0.7535
# 22/12/2021   0.7488
# 23/12/2021   0.7457
# 29/12/2021   0.7412

# %%
# AUTOREGRESSION MODEL 
# USD / GBP 
ar_model = AutoReg(gbp_train, lags=100) # lag = 1 (1 period)  #We define the model direclty for the train set 
model_fit = ar_model.fit()
ar_predictions_gbp = model_fit.predict(start=len(gbp_train), end=len(gbp_train)+len(gbp_test)-1, dynamic=False)
plt.title("GBP")
plt.xlabel('price(st)')
plt.ylabel('time')
plt.plot(ar_predictions_gbp)
plt.plot(gbp_test, color='red')
# Model accuracy
MSE_AR_gbp = np.square(np.subtract(gbp_test,ar_predictions_gbp)).mean() 
RMSE_AR_gbp = math.sqrt(MSE_gbp)
print("Root Mean Square Error:", RMSE_AR_gbp)
print("Mean Square Error:     ",MSE_AR_gbp)
print("error %:               " , MSE_AR_gbp/np.mean(gbp_test_scal))
###### To be adapted with new DFs

# # USD / EUR 
# ar_model = AutoReg(gbp_train_scal, lags=200) # lag = 1 (1 period)  #We define the model direclty for the train set 
# model_fit = ar_model.fit()
# ar_predictions_eur = model_fit.predict(start=len(gbp_train_scal), end=len(gbp_train_scal)+len(gbp_test_scal)-1, dynamic=False)
# plt.title("EUR")
# plt.xlabel('price(st)')
# plt.ylabel('time')
# plt.plot(ar_predictions_gbp)
# plt.plot(gbp_test_scal, color='red')
# Model accuracy
# MSE_gbp = np.square(np.subtract(gbp_test_scal,ar_predictions_gbp)).mean() 
# RMSE_gbp = math.sqrt(MSE_gbp)
# print("Root Mean Square Error:\n")
# print(RMSE_gbp)


# # USD / YUAN 
# ar_model = AutoReg(gbp_train_scal, lags=200) # lag = 1 (1 period)  #We define the model direclty for the train set 
# model_fit = ar_model.fit()
# ar_predictions_eur = model_fit.predict(start=len(gbp_train_scal), end=len(gbp_train_scal)+len(gbp_test_scal)-1, dynamic=False)
# plt.title("EUR")
# plt.xlabel('price(st)')
# plt.ylabel('time')
# plt.plot(ar_predictions_gbp)
# plt.plot(gbp_test_scal, color='red')
# Model accuracy
# MSE_gbp = np.square(np.subtract(gbp_test_scal,ar_predictions_gbp)).mean() 
# RMSE_gbp = math.sqrt(MSE_gbp)
# print("Root Mean Square Error:\n")
# print(RMSE_gbp)
#The rpedictions are following the trend more than the fluctuation


# # BTC 
# ar_model = AutoReg(gbp_train_scal, lags=200) # lag = 1 (1 period)  #We define the model direclty for the train set 
# model_fit = ar_model.fit()
# ar_predictions_eur = model_fit.predict(start=len(gbp_train_scal), end=len(gbp_train_scal)+len(gbp_test_scal)-1, dynamic=False)
# plt.title("EUR")
# plt.xlabel('price(st)')
# plt.ylabel('time')
# plt.plot(ar_predictions_gbp)
# plt.plot(gbp_test_scal, color='red')
# Model accuracy
# MSE_gbp = np.square(np.subtract(gbp_test_scal,ar_predictions_gbp)).mean() 
# RMSE_gbp = math.sqrt(MSE_gbp)
# print("Root Mean Square Error:\n")
# print(RMSE_gbp)

# # QQQQQQQQQQQQQQQQQ preditoins come standardized?
# Out:
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/deterministic.py:147: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Int64Indexes with a unit increment support extending. The index is set will contain the position relative to the data length.
#   warnings.warn(
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_33336/2002080683.py:12: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   MSE_AR_gbp = np.square(np.subtract(gbp_test,ar_predictions_gbp)).mean()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_33336/2002080683.py in <module>
#      10 plt.plot(gbp_test, color='red')
#      11 # Model accuracy
# ---> 12 MSE_AR_gbp = np.square(np.subtract(gbp_test,ar_predictions_gbp)).mean()
#      13 RMSE_AR_gbp = math.sqrt(MSE_gbp)
#      14 print("Root Mean Square Error:", RMSE_AR_gbp)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2030         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031     ):
# -> 2032         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2033
#    2034     # ideally we would define this to avoid the getattr checks, but
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     246
#     247     # for backwards compatibility check and potentially fallback for non-aligned frames
# --> 248     result = _maybe_fallback(ufunc, method, *inputs, **kwargs)
#     249     if result is not NotImplemented:
#     250         return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in _maybe_fallback(ufunc, method, *inputs, **kwargs)
#     226
#     227             # call the ufunc on those transformed inputs
# --> 228             return getattr(ufunc, method)(*new_inputs, **kwargs)
#     229
#     230     # signal that we didn't fallback / execute the ufunc yet
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2030         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2031     ):
# -> 2032         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2033
#    2034     # ideally we would define this to avoid the getattr checks, but
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     251
#     252     # for binary ops, use our custom dunder methods
# --> 253     result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     254     if result is not NotImplemented:
#     255         return result
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/ops_dispatch.pyx in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __sub__(self, other)
#      98     @unpack_zerodim_and_defer("__sub__")
#      99     def __sub__(self, other):
# --> 100         return self._arith_method(other, operator.sub)
#     101
#     102     @unpack_zerodim_and_defer("__rsub__")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    6862         other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
#    6863
# -> 6864         self, other = ops.align_method_FRAME(self, other, axis, flex=True, level=None)
#    6865
#    6866         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/__init__.py in align_method_FRAME(left, right, axis, flex, level)
#     245
#     246         if right.ndim == 1:
# --> 247             right = to_series(right)
#     248
#     249         elif right.ndim == 2:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/__init__.py in to_series(right)
#     236         else:
#     237             if len(left.columns) != len(right):
# --> 238                 raise ValueError(
#     239                     msg.format(req_len=len(left.columns), given_len=len(right))
#     240                 )
#
# ValueError: Unable to coerce to Series, length must be 1: given 50

# %%
# H0: series is not stationary
# H1: series is stationary
adfuller(curr_btc.usd_gbp)[1] # p-value = 0.02,... We reject H0, the series is stationary (Hard to predict long term)
# Does this mean it should be done first?
# Out:
# 0.020088601836270713

# %%
# ARIMA 
model = ARIMA(train, order=(50, 1, 0)) 
# p = number of lag terms taken into account, periods back
# d = number of times the terms are differenced
# q = moving average window
model_fit = model.fit()
predictions = model_fit.predict(len(curr_btc.usd_gbp)-50, len(curr_btc.usd_gbp)-1)
# We convert to DF and reset index to compare with test values 
predict_gbp = pd.DataFrame(predictions)
predict_gbp = predict_gbp.reset_index(drop=True)
predict_gbp = predict_gbp.rename({'predicted_mean':"predicted"}, axis=1)
# make a DF with predictions Vs actual (test) values 
check_gbp = curr_btc[['usd_gbp']].tail(50)
check_gbp = check_gbp.reset_index(drop=True)
compare_gbp_pred = pd.concat([check_gbp,predict_gbp],axis=1,join="inner",ignore_index=False,sort=False, copy=False) 
compare_gbp_pred['error'] = compare_gbp_pred['usd_gbp'] - compare_gbp_pred['predicted']
compare_gbp_pred
# Model accuracy
MSE_ARIMA_gbp = np.square(np.subtract(check_gbp,predict_gbp)).mean() 
RMSE_ARIMA_gbp = math.sqrt(MSE)
print("Root Mean Square Error: ",RMSE_ARIMA_gbp)
print("Mean Square Error:      ",MSE_ARIMA_gbp)
print("error %:                ",MSE_ARIMA_gbp/np.mean(check_gbp))
# Out:
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# Root Mean Square Error:  0.011666837777515855
# Mean Square Error:       usd_gbp    0.000136
# dtype: float64
# error %:                 usd_gbp    0.000184
# dtype: float64
# /Users/chrislacarte/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:376: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_28830/1539401918.py:19: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   MSE_ARIMA_gbp = np.square(np.subtract(check_gbp,predict_gbp)).mean()

# %%
# Out:
# Root Mean Square Error:  0.011666837777515855
# Mean Square Error:       usd_gbp    0.000136
# dtype: float64
# error %:                 usd_gbp    0.000184
# dtype: float64
# /var/folders/hq/x_513gjd2qsd86w2rwvd665m0000gn/T/ipykernel_28830/1591416696.py:2: FutureWarning: Calling a ufunc on non-aligned DataFrames (or DataFrame/Series combination). Currently, the indices are ignored and the result takes the index/columns of the first DataFrame. In the future , the DataFrames/Series will be aligned before applying the ufunc.
# Convert one of the arguments to a NumPy array (eg 'ufunc(df1, np.asarray(df2)') to keep the current behaviour, or align manually (eg 'df1, df2 = df1.align(df2)') before passing to the ufunc to obtain the future behaviour and silence this warning.
#   MSE_ARIMA_gbp = np.square(np.subtract(check_gbp,predict_gbp)).mean()

# %%
# !conda install -c anaconda ephem
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab_server==2.8.2=pyhd3eb1b0_0
#   - defaults/noarch::cookiecutter==1.7.2=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/noarch::nbclassic==0.2.6=pyhd3eb1b0_0
#   - defaults/noarch::urllib3==1.26.7=pyhd3eb1b0_0
#   - defaults/noarch::sphinx==4.2.0=pyhd3eb1b0_1
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::scikit-learn-intelex==2021.3.0=py39hecd8cb5_0
#   - defaults/osx-64::anaconda-navigator==2.1.4=py39hecd8cb5_0
#   - defaults/osx-64::anyio==2.2.0=py39hecd8cb5_1
#   - defaults/osx-64::anaconda==2021.11=py39_0
#   - defaults/osx-64::anaconda-client==1.9.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_0
#   - defaults/noarch::jupyterlab==3.2.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==5.1.5=py39hecd8cb5_1
#   - defaults/osx-64::jupyter_server==1.4.1=py39hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.12.0=py39hecd8cb5_0
#   - defaults/osx-64::conda-build==3.21.5=py39hecd8cb5_0
#   - defaults/noarch::anaconda-project==0.10.1=pyhd3eb1b0_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -

# %%
# !conda install -c conda-forge pystan

# %%
# !conda install -c conda-forge fbprophet

# %%
# !pip install holidays==0.9.12

# %%
# #  USD / GBP 
# gbp_train, gbp_test = curr_btc["usd_gbp"][:-50], curr_btc["usd_gbp"][-50:]


# # Convert to DF
# gbp_train = pd.DataFrame(train)
# gbp_test = pd.DataFrame(test)

# %%
# PROPHET

# prepare expected column names
# df.columns = ['gbp_test', 'pred']


# define the model
model = Prophet()
# fit the model
model.fit(gbp_train)

# use the model to make a forecast
forecast = model.predict(gbp_tes)
# summarize the forecast
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())
# plot forecast
model.plot(forecast)
pyplot.show()

# %%
# !git add .

# %%
! git commit -m'all data ready to start analysis'
# Out:
# [main 23a9aab] all data ready to start analysis
#  2 files changed, 2317 insertions(+), 11 deletions(-)
#  create mode 100644 code/.ipynb_checkpoints/data_analysis-checkpoint.ipynb

# %%
! git push
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 4 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 450.57 KiB | 7.15 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/chrislacarte/crypto_analysis
#    2abf036..23a9aab  main -> main
